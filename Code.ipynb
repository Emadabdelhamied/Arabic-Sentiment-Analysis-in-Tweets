# %% [markdown]
# ## **Coding**

# %%
#Postive and negative dataset 
#!/usr/bin/python
#-*-coding :utf8 -*-
from __future__ import unicode_literals
import re
import nltk
nltk.download('punkt')
file=nltk.data.load("/content/data_set.csv",format="raw")
dfile=file.decode("utf-8")
print(dfile[0:1000])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# class,text,,,,,,,,,
# neg,اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد 😭,,,,,,,,,
# neg,توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم 💔 #Avlu,,,,,,,,,
# neg,#الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال والاهلي تحت التاق 👇 #تحدي_اسرع_روقان وادخل في سحب قيمة ايفون X على…,,,,,,,,,
# neg,نعمة المضادات الحيوية . تضع قطرة💧مضاد بنسلين على بكتيريا 🦠 فتنفجر 💥 و تموت . الأخيرة يبدو انها بكتيريا مقاومة فأخذ…,,,,,,,,,
# neg,الدودو جايه تكمل علي 💔,,,,,,,,,
# neg,أحببته حتى أقنعنى إن ما فات من العمر كان إنتظار له 🙈,,,,,,,,,
# neg,يبدو ان دجلة اعتادت على التهام اجساد ابنائها من سبايكر للعبارة ..👆👆💔 ما سمعته .. ان البشر يعطش فيشرب الماء .. لم…,,,,,,,,,
# neg,جالس أذاكر 😣,,,,,,,,,
# neg,يكفي استخفاف بالعقل العربي هل حقا الأمن والمخابرات في ألمانيا غير قادرة على وقف اي عصابة أو الجريمة 🤔 وا…,,,,,,,,,
# neg,ياليلل ترا اكلج كثير مشي 😭,,,,,,,,,
# ...

# %%
#segmentation of dataset by english pickle segmenter
def segment(text):
    sens_token=nltk.data.load("tokenizers/punkt/english.pickle")
    sentences=sens_token.tokenize(text)
    text=str(sentences).encode("utf-8")
    dtext=text.decode("utf-8")
    print(dtext)
segment(dfile[0:1000])
# Out:
# ['class,text,,,,,,,,,\nneg,اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد 😭,,,,,,,,,\nneg,توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم 💔 #Avlu,,,,,,,,,\nneg,#الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال والاهلي تحت التاق 👇 #تحدي_اسرع_روقان وادخل في سحب قيمة ايفون X على…,,,,,,,,,\nneg,نعمة المضادات الحيوية .', 'تضع قطرة💧مضاد بنسلين على بكتيريا 🦠 فتنفجر 💥 و تموت .', 'الأخيرة يبدو انها بكتيريا مقاومة فأخذ…,,,,,,,,,\nneg,الدودو جايه تكمل علي 💔,,,,,,,,,\nneg,أحببته حتى أقنعنى إن ما فات من العمر كان إنتظار له 🙈,,,,,,,,,\nneg,يبدو ان دجلة اعتادت على التهام اجساد ابنائها من سبايكر للعبارة ..👆👆💔 ما سمعته .. ان البشر يعطش فيشرب الماء .. لم…,,,,,,,,,\nneg,جالس أذاكر 😣,,,,,,,,,\nneg,يكفي استخفاف بالعقل العربي هل حقا الأمن والمخابرات في ألمانيا غير قادرة على وقف اي عصابة أو الجريمة 🤔 وا…,,,,,,,,,\nneg,ياليلل ترا اكلج كثير مشي 😭,,,,,,,,,\nneg,لو بيدي أرجع ساعتي وين أرجع؟ إليا صدفه؟ والله أبقى أفر بيها لما ترجع بشر ماعرفه!', 'وأنهي العلاقة من العرق.. قبل الدمع…,,,,,,,,,\n
# ...

# %%
stmts=[]
def Segmentation (text):
    stmts=text.split("\t")
    print(str(stmts).encode('utf-8').decode('utf-8'))
Segmentation(dfile[0:1000])
# Out:
# ['class,text,,,,,,,,,\nneg,اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد 😭,,,,,,,,,\nneg,توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم 💔 #Avlu,,,,,,,,,\nneg,#الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال والاهلي تحت التاق 👇 #تحدي_اسرع_روقان وادخل في سحب قيمة ايفون X على…,,,,,,,,,\nneg,نعمة المضادات الحيوية . تضع قطرة💧مضاد بنسلين على بكتيريا 🦠 فتنفجر 💥 و تموت . الأخيرة يبدو انها بكتيريا مقاومة فأخذ…,,,,,,,,,\nneg,الدودو جايه تكمل علي 💔,,,,,,,,,\nneg,أحببته حتى أقنعنى إن ما فات من العمر كان إنتظار له 🙈,,,,,,,,,\nneg,يبدو ان دجلة اعتادت على التهام اجساد ابنائها من سبايكر للعبارة ..👆👆💔 ما سمعته .. ان البشر يعطش فيشرب الماء .. لم…,,,,,,,,,\nneg,جالس أذاكر 😣,,,,,,,,,\nneg,يكفي استخفاف بالعقل العربي هل حقا الأمن والمخابرات في ألمانيا غير قادرة على وقف اي عصابة أو الجريمة 🤔 وا…,,,,,,,,,\nneg,ياليلل ترا اكلج كثير مشي 😭,,,,,,,,,\nneg,لو بيدي أرجع ساعتي وين أرجع؟ إليا صدفه؟ والله أبقى أفر بيها لما ترجع بشر ماعرفه! وأنهي العلاقة من العرق.. قبل الدمع…,,,,,,,,,\nneg,ليه م
# ...

# %%
#tokenize dataset by wordtokenize
def Tokenize ():
    tokens=dfile.split('\t')
    return tokens[0:1000]
def tokenize(text):
    stmts=nltk.word_tokenize(text)
    text=str(stmts).encode("utf-8")
    dtext=text.decode("utf-8")
    print(dtext)
tokenize(dfile[0:1000])
# Out:
# ['class', ',', 'text', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'neg', ',', 'اعترف', 'ان', 'بتس', 'كانو', 'شوي', 'شوي', 'يجيبو', 'راسي', 'لكن', 'اليوم', 'بالزايد', '😭', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'neg', ',', 'توقعت', 'اذا', 'جات', 'داريا', 'بشوفهم', 'كاملين', 'بس', 'لي', 'للحين', 'احس', 'فيه', 'احد', 'ناقصهم', '💔', '#', 'Avlu', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'neg', ',', '#', 'الاهلي_الهلال', 'اكتب', 'توقعك', 'لنتيجة', 'لقاء', 'الهلال', 'والاهلي', 'تحت', 'التاق', '👇', '#', 'تحدي_اسرع_روقان', 'وادخل', 'في', 'سحب', 'قيمة', 'ايفون', 'X', 'على…', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'neg', ',', 'نعمة', 'المضادات', 'الحيوية', '.', 'تضع', 'قطرة💧مضاد', 'بنسلين', 'على', 'بكتيريا', '🦠', 'فتنفجر', '💥', 'و', 'تموت', '.', 'الأخيرة', 'يبدو', 'انها', 'بكتيريا', 'مقاومة', 'فأخذ…', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'neg', ',', 'الدودو', 'جايه', 'تكمل', 'علي', '💔', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'neg', ',', 'أحببته', 'حتى', 'أقنعنى',
# ...

# %%
#alphanumeric removal
letters=re.sub(r"[a-zA-Z0-9]+","",dfile[0:20000])
print(letters)
# Out:
# ,,,,,,,,,,
# ,اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد 😭,,,,,,,,,
# ,توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم 💔 #,,,,,,,,,
# ,#الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال والاهلي تحت التاق 👇 #تحدي_اسرع_روقان وادخل في سحب قيمة ايفون  على…,,,,,,,,,
# ,نعمة المضادات الحيوية . تضع قطرة💧مضاد بنسلين على بكتيريا 🦠 فتنفجر 💥 و تموت . الأخيرة يبدو انها بكتيريا مقاومة فأخذ…,,,,,,,,,
# ,الدودو جايه تكمل علي 💔,,,,,,,,,
# ,أحببته حتى أقنعنى إن ما فات من العمر كان إنتظار له 🙈,,,,,,,,,
# ,يبدو ان دجلة اعتادت على التهام اجساد ابنائها من سبايكر للعبارة ..👆👆💔 ما سمعته .. ان البشر يعطش فيشرب الماء .. لم…,,,,,,,,,
# ,جالس أذاكر 😣,,,,,,,,,
# ,يكفي استخفاف بالعقل العربي هل حقا الأمن والمخابرات في ألمانيا غير قادرة على وقف اي عصابة أو الجريمة 🤔 وا…,,,,,,,,,
# ,ياليلل ترا اكلج كثير مشي 😭,,,,,,,,,
# ,لو بيدي أرجع ساعتي وين أرجع؟ إليا صدفه؟ والله أبقى أفر بيها لما ترجع بشر ماعرفه! وأنهي العلاقة من العرق.. قبل الدمع…,,,,,,,,,
# ,ليه محد يسوي معي كذا 💔,,,,,,,,,
# ...

# %%
#special characters removal
s=re.sub(r"\,|\.|\*|\#|\؟|\!|$|❀ ♪ ┈┈••✦✿​​❥​​• ​​❥⇣•​​ ↓˓❁|\~|،|:| ﴾|​﴿|ﷻ|☕︎❤︎|❤|❥ ┈・ ✦̣̇•…|♩   ⌗|☞ ✧✦•✦✧|┈┉━◈♔♚♔◈━┅┄ |✿|◌⊰•ั◕|\[|\]|♔➥|⇣ ┊┊⇣ ┊⇣ ⇣ |¸¸•°˚˚° ⇣|\/|\(|\)|_|-","",letters)
print(s)
# Out:
# اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد 😭
# توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم 💔
# الاهليالهلال اكتب توقعك لنتيجة لقاء الهلال والاهلي تحت التاق 👇 تحدياسرعروقان وادخل في سحب قيمة ايفون  على…
# نعمة المضادات الحيوية  تضع قطرة💧مضاد بنسلين على بكتيريا 🦠 فتنفجر 💥 و تموت  الأخيرة يبدو انها بكتيريا مقاومة فأخذ…
# الدودو جايه تكمل علي 💔
# أحببته حتى أقنعنى إن ما فات من العمر كان إنتظار له 🙈
# يبدو ان دجلة اعتادت على التهام اجساد ابنائها من سبايكر للعبارة 👆👆💔 ما سمعته  ان البشر يعطش فيشرب الماء  لم…
# جالس أذاكر 😣
# يكفي استخفاف بالعقل العربي هل حقا الأمن والمخابرات في ألمانيا غير قادرة على وقف اي عصابة أو الجريمة 🤔 وا…
# ياليلل ترا اكلج كثير مشي 😭
# لو بيدي أرجع ساعتي وين أرجع إليا صدفه والله أبقى أفر بيها لما ترجع بشر ماعرفه وأنهي العلاقة من العرق قبل الدمع…
# ليه محد يسوي معي كذا 💔
#     انت يمكن الي ناسي احداث البصرة قبل شهور او متغافل عنها نقتلوا متظاهرين بدم بارد منو قتلهم 😕
# الله يعين بس 😔
# ...

# %%
def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)
clean=remove_emojis(s)
print(clean)
# Out:
# اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد
# توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم
# الاهليالهلال اكتب توقعك لنتيجة لقاء الهلال والاهلي تحت التاق  تحدياسرعروقان وادخل في سحب قيمة ايفون  على…
# نعمة المضادات الحيوية  تضع قطرةمضاد بنسلين على بكتيريا  فتنفجر  و تموت  الأخيرة يبدو انها بكتيريا مقاومة فأخذ…
# الدودو جايه تكمل علي
# أحببته حتى أقنعنى إن ما فات من العمر كان إنتظار له
# يبدو ان دجلة اعتادت على التهام اجساد ابنائها من سبايكر للعبارة  ما سمعته  ان البشر يعطش فيشرب الماء  لم…
# جالس أذاكر
# يكفي استخفاف بالعقل العربي هل حقا الأمن والمخابرات في ألمانيا غير قادرة على وقف اي عصابة أو الجريمة  وا…
# ياليلل ترا اكلج كثير مشي
# لو بيدي أرجع ساعتي وين أرجع إليا صدفه والله أبقى أفر بيها لما ترجع بشر ماعرفه وأنهي العلاقة من العرق قبل الدمع…
# ليه محد يسوي معي كذا
#     انت يمكن الي ناسي احداث البصرة قبل شهور او متغافل عنها نقتلوا متظاهرين بدم بارد منو قتلهم
# الله يعين بس
# ...

# %%
# removal from dataset
def noramlize(Tweet):
    Tweet = re.sub(r"[إأٱآا]", "ا", Tweet)
    Tweet = re.sub(r"ى", "ي", Tweet)
    Tweet = re.sub(r"ؤ", "ء", Tweet)
    Tweet = re.sub(r"ئ", "ء", Tweet)
    Tweet = re.sub(r'[^ا-ي ]', "", Tweet)

    noise = re.compile(""" ّ    | # Tashdid
                         َ    | # Fatha
                         ً    | # Tanwin Fath
                         ُ    | # Damma
                         ٌ    | # Tanwin Damm
                         ِ    | # Kasra
                         ٍ    | # Tanwin Kasr
                         ْ    | # Sukun
                         ـ     # Tatwil/Kashida
                     """, re.VERBOSE)
    Tweet = re.sub(noise, '', Tweet)
    return Tweet
noramlize(s)
# Out:
# 'اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم بالزايد توقعت اذا جات داريا بشوفهم كاملين بس لي للحين احس فيه احد ناقصهم  الاهليالهلال اكتب توقعك لنتيجة لقا الهلال والاهلي تحت التاق  تحدياسرعروقان وادخل في سحب قيمة ايفون  علينعمة المضادات الحيوية  تضع قطرةمضاد بنسلين علي بكتيريا  فتنفجر  و تموت  الاخيرة يبدو انها بكتيريا مقاومة فاخذالدودو جايه تكمل علي احببته حتي اقنعني ان ما فات من العمر كان انتظار له يبدو ان دجلة اعتادت علي التهام اجساد ابناها من سبايكر للعبارة  ما سمعته  ان البشر يعطش فيشرب الما  لمجالس اذاكر يكفي استخفاف بالعقل العربي هل حقا الامن والمخابرات في المانيا غير قادرة علي وقف اي عصابة او الجريمة  واياليلل ترا اكلج كثير مشي لو بيدي ارجع ساعتي وين ارجع اليا صدفه والله ابقي افر بيها لما ترجع بشر ماعرفه وانهي العلاقة من العرق قبل الدمعليه محد يسوي معي كذا     انت يمكن الي ناسي احداث البصرة قبل شهور او متغافل عنها نقتلوا متظاهرين بدم بارد منو قتلهم الله يعين بس اتفرج علي ادااتهم امس تقريبا كلهم قربوا من الفانز الا بوبي من بعيد ياسر مدري ليه  تبي شي يقويك جنسيا   فوريفر تعطي
# ...

# %%
#stopwords removal
#stemming of dataset
#lemmtizing dataset
from nltk.stem.isri import ISRIStemmer
st = ISRIStemmer()
for token in clean.split():
     print (st.stem(token))
# Out:
# عرف
# ان
# بتس
# كنو
# شوي
# شوي
# جيبو
# رسي
# لكن
# اليوم
# زيد
# وقع
# اذا
# جات
# دار
# بشف
# كمل
# بس
# لي
# حين
# احس
# فيه
# احد
# نقص
# اهليالهلال
# كتب
# وقع
# نتج
# لقء
# هلل
# اهل
# تحت
# تاق
# تحدياسرعروق
# دخل
# في
# سحب
# قيم
# ايف
# على…
# نعم
# ضاد
# حيي
# تضع
# قطرةمضاد
# نسل
# على
# كتر
# فجر
# و
# تمت
# خير
# بدو
# انه
# كتر
# قام
# أخذ…
# دودو
# جيه
# كمل
# علي
# حبب
# حتى
# قنعنى
# ان
# ما
# فات
# من
# عمر
# كان
# نظر
# له
# بدو
# ان
# دجل
# عاد
# على
# تهم
# جسد
# بنئ
# من
# يكر
# عبر
# ما
# سمع
# ان
# بشر
# عطش
# شرب
# ماء
# لم…
# جلس
# ذكر
# يكف
# خفف
# عقل
# عرب
# هل
# حقا
# امن
# خبر
# في
# لمن
# غير
# قدر
# على
# وقف
# اي
# عصب
# او
# جرم
# وا…
# يلل
# ترا
# كلج
# كثر
# مشي
# لو
# بيد
# رجع
# سعت
# وين
# رجع
# الا
# صدف
# ولل
# بقى
# افر
# بيه
# لما
# رجع
# بشر
# اعرف
# وأن
# علق
# من
# عرق
# قبل
# دمع…
# ليه
# محد
# يسي
# معي
# كذا
# انت
# يمكن
# الي
# نسي
# حدث
# بصر
# قبل
# شهر
# او
# غافل
# عنه
# قتل
# ظاهر
# بدم
# برد
# منو
# قتل
# الل
# يعن
# بس
# ...

# %%
# !pip install tashaphyne
import tashaphyne
from tashaphyne.stemming import ArabicLightStemmer
ArListem = ArabicLightStemmer()
word = u'أفتضاربانني'
stem = ArListem.light_stem(word)
print (ArListem.get_stem()) 
print (ArListem.get_root()) 
print( ArListem.get_prefix())
print(ArListem.get_suffix())
print(ArListem.get_affix())
# Out:
# ...
#      |████████████████████████████████| 251 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 126 kB 53.1 MB/s
# ...
# ضارب
# ضرب
# أفت
# انني
# أفت-انني

# %% [markdown]
# ## **GUI**

# %%
#GUI programming
from tkinter import *
import tkinter as tk
import tkinter.messagebox
def postive_Tweet():
    tkinter.messagebox.showinfo("message","Postive tweet :)")
def negative_Tweet():
    tkinter.messagebox.showinfo("message","negative tweet :(")
top=tk.Tk()
top.title("Tweets Type")
top.geometry("300x300")
but1=Button(top,text="Postive",fg="green",command=postive_Tweet)
but1.grid(row=2,column=1,padx=50,pady=10,ipadx=10)
but2=Button(top,text="Negative",fg="red",command=negative_Tweet)
but2.grid(row=2,column=2,padx=10,pady=150,ipadx=10)
top.mainloop()

# %% [markdown]
# ![Form.png](data:image/png;base64,...)

# %%
#two buttons postive and negative
def btn_click(string1,string2):
    text=string1
    pat=string2
    ls=text.split()
    research=[w for w in ls if re.search(string2,w)]
    for w in research :
        print("postive tweet :)")
    
def GUI():
    root=Tk()
    root.geometry("300x300")
    root.title("search form")
    lb=Label(root,text="Enter text")
    lb.grid(row=0,column=0)
    txt=Entry(root)
    txt.grid(row=0,column=1)
    
    lb1=Label(root,text="Enter pattern")
    lb1.grid(row=1,column=0)
    txt1=Entry(root)
    txt1.grid(row=1,column=1)
    btn=Button(root,text="click",command=lambda:btn_click(txt.get(),txt1.get()))
    btn.grid(row=3,column=0)
    root.mainloop()
GUI()
# Out:
# postive tweet :)

# %% [markdown]
# ![Form1.png](data:image/png;base64,...)

# %%
#form for tokenization
def btn(string1):
    text=string1
    ls=text.split()
    for s in ls:
        print(s)
def GUI():
    root=Tk()
    root.geometry("300x300")
    root.title("Tokenize form")
    lb=Label(root,text="Enter text")
    lb.grid(row=0,column=0)
    global txt
    txt=Entry(root,width=30)
    txt.grid(row=0,column=1)
    but=Button(root,text="click",command=lambda:btn(txt.get()))
    but.grid(row=3,column=0,ipadx=12,ipady=12)
    root.mainloop()
GUI()
# Out:
# نحن
# شباب
# المستقبل

# %% [markdown]
# ![Form2.png](data:image/png;base64,...)
